# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("meteorite-landings.csv")

# %%
df.head()
# Out:
#        name   id nametype     recclass      mass  fall  year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1970  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1970  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1970  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1970  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1970 -33.16667
#
#      reclong               GeoLocation
# 0    6.08333     (50.775000, 6.083330)
# 1   10.23333    (56.183330, 10.233330)
# 2 -113.00000  (54.216670, -113.000000)
# 3  -99.90000   (16.883330, -99.900000)
# 4  -64.95000  (-33.166670, -64.950000)

# %%
print("Key Insights: ")
print(f"Total meteorites in dataset: {len(df)}")
# Out:
# Key Insights:
# Total meteorites in dataset: 38226

# %%
print(f"Largest meteorite mass: {df['mass'].max():,.0f} ")
# Out:
# Largest meteorite mass: 60,000,000

# %%
print(f"Smallest meteorite mass: {df['mass'].min():,.2f} ")
# Out:
# Smallest meteorite mass: 0.00

# %%
print(f"Most common meteorite type: {df['recclass'].mode()[0]}")
# Out:
# Most common meteorite type: L6

# %%
df = df.dropna(subset=['reclat', 'reclong'])

# %%
df['year'] = pd.to_datetime(df['year'], errors='coerce').dt.year

# %%
df = df.dropna(subset=['year'])

# %%
print("Data After Cleaning:")
print(df.info())
# Out:
# Data After Cleaning:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38226 entries, 0 to 45715
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         38226 non-null  object
#  1   id           38226 non-null  int64
#  2   nametype     38226 non-null  object
#  3   recclass     38226 non-null  object
#  4   mass         38116 non-null  float64
#  5   fall         38226 non-null  object
#  6   year         38226 non-null  int32
#  7   reclat       38226 non-null  float64
#  8   reclong      38226 non-null  float64
#  9   GeoLocation  38226 non-null  object
# dtypes: float64(3), int32(1), int64(1), object(5)
# memory usage: 3.1+ MB
# None

# %%
#       10 Largest Meteorites
plt.title(" Top 10 Largest Meterorites")
sns.barplot(
    x='mass', 
    y='name', 
    data=largest, 
    hue='name',  
    palette='viridis', 
    legend=False  
)
# Out:
# <Axes: title={'center': ' Top 10 Largest Meterorites'}, xlabel='mass', ylabel='name'>

# %%
#   Meteorite Landings Over the Years
plt.figure(figsize=(6,5))
sns.histplot(df['year'], bins=50, color='blue')
plt.title("Meteorite Landings Over the Years")
plt.xlabel("Year")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %%
#      Most Common Meteorite Types  
plt.figure(figsize=(8,4))
df['recclass'].value_counts().head(10).plot(kind='bar', color='skyblue')
plt.title("Top 10 Meteorite Types")
plt.xlabel("Type")
plt.ylabel("Count")
plt.tight_layout()
plt.show()
print("Analysis Complete!")
# Out:
# Analysis Complete!
